# %% [markdown]
# # Understanding of T2 Maps

# %%
import sys
sys.path.append('../src')

# %%
import matplotlib.pyplot as plt
import numpy as np
from torch.utils.data import DataLoader
from AortaDataset import AortaDataset
#%matplotlib inline
# Out:
# /home/joshy/anaconda3/envs/deep/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
train_set = AortaDataset()
image, mask = train_set[50]
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
plt.hist(image.ravel(), bins=50)
plt.show()

# %%
plt.imshow(image)

# %%
np.std(image), np.mean(image)
# Out:
# (90.83814014521776, 81.18147561443932)

# %%
len(train_set)
# Out:
# 93

# %%
all_images = [x[0] for x in train_set]
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1
# ...

# %%
sizes = [x.shape for x in all_images]

# %%
minx = np.min(sizes[0])

# %%
miny = np.min(sizes[1])

# %%
minx, miny
# Out:
# (204, 222)

# %%
minx = np.min([x[0] for x in sizes])
miny = np.min([x[1] for x in sizes])
minx, miny
# Out:
# (174, 224)

# %%
np.std([x[0:minx, 0:miny] for x in all_images])
# Out:
# 90.40952305336529

# %%
np.mean([x[0:minx, 0:miny] for x in all_images])
# Out:
# 88.78629942661158
