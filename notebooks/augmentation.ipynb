# %% [markdown]
# # Data augmentation

# %%
import sys
sys.path.append('../src')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import nibabel as nib
import utils
import matplotlib.pyplot as plt
from skimage.util import montage
import numpy as np
from AortaDataset import AortaDataset
from torchvision.transforms import Compose
import augment
# %matplotlib inline

# %%
flipud = augment.FlipUD()
fliplr = augment.FlipLR()
crop = augment.RandomCrop()
resize = augment.Resize(512, 388)

# %%
composed = Compose([flipud, fliplr, crop, resize])

# %%
aorta_train_dataset = AortaDataset(transform=composed)

# %%
image, mask = aorta_train_dataset[0]
# Out:
# pixdim[1,2,3] should be non-zero; setting 0 dims to 1

# %%
plt.imshow(image)

# %%
plt.imshow(mask)
